# %%
# Import
from configs import Configs
from train import TrainSimpleTTS

# %%
# Train
config = Configs()
trainer = TrainSimpleTTS(config, device="cuda:3")
trainer.train()
# Out:
# Using device: cuda:3
# train_saved_path: /app/Simple-TTS/_saved_dir/params/train_SimpleTTS.pt
# test_saved_path: /app/Simple-TTS/_saved_dir/params/test_SimpleTTS.pt
# /app/Simple-TTS/train/TrainSimpleTTS.py:232: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
# Load: 108001; test_loss: 0.32211; train_loss: 0.31319
# 2-109000) Train loss: 0.31246; Duration: 415.683 sec.
# 4-110000) Train loss: 0.31268; Duration: 374.707 sec.
# 7-111000) Train loss: 0.31233; Duration: 375.703 sec.
